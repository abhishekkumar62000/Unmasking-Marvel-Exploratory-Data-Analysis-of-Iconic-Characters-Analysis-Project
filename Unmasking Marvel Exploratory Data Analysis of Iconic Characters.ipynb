# %% [markdown]
# ### Author:---> Abhishek Kumar
# ### Project:---> "Unmasking Marvel: Exploratory Data Analysis of Iconic Characters"

# %% [markdown]
# ![pngwing.com (1).png](attachment:d55564e8-74a3-4158-8542-46b3893bedc4.png)

# %% [markdown]
# ![pngwing.com.png](attachment:de362031-2fe2-43db-b52e-00d42c8c4ada.png)

# %%
from IPython.display import Image

Image('marvel-2.jpg')

# %% [markdown]
# IMPORTING DEPENDENCIES

# %% [markdown]
# ### Step1:---> Import all the important Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step2:--> Now Load the dataset from the Marvel CSV file

# %%
marvel = pd.read_csv('marvel-data.csv')

# %% [markdown]
# ### Step3:--> Read the Top 5 Rows of the dataset

# %%
marvel.head()
# Out:
#    page_id                                 name  \
# 0     1678            Spider-Man (Peter Parker)
# 1     7139      Captain America (Steven Rogers)
# 2    64786  Wolverine (James \"Logan\" Howlett)
# 3     1868    Iron Man (Anthony \"Tony\" Stark)
# 4     2460                  Thor (Thor Odinson)
#
#                                    urlslug                ID  \
# 0              \/Spider-Man_(Peter_Parker)   Secret Identity
# 1        \/Captain_America_(Steven_Rogers)   Public Identity
# 2  \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3    \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 4                    \/Thor_(Thor_Odinson)  No Dual Identity
#
#                 ALIGN         EYE        HAIR              SEX  GSM  \
# 0     Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 1     Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 2  Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# ...

# %% [markdown]
# ### Step5:---> Read the Last 5 rows of the dataset

# %%
marvel.tail()
# Out:
#        page_id                             name  \
# 16371   657508               Ru'ach (Earth-616)
# 16372   665474  Thane (Thanos' son) (Earth-616)
# 16373   695217    Tinkerer (Skrull) (Earth-616)
# 16374   708811   TK421 (Spiderling) (Earth-616)
# 16375   673702            Yologarch (Earth-616)
#
#                                    urlslug                ID  \
# 16371               \/Ru%27ach_(Earth-616)  No Dual Identity
# 16372  \/Thane_(Thanos%27_son)_(Earth-616)  No Dual Identity
# 16373      \/Tinkerer_(Skrull)_(Earth-616)   Secret Identity
# 16374     \/TK421_(Spiderling)_(Earth-616)   Secret Identity
# 16375              \/Yologarch_(Earth-616)               NaN
#
#                     ALIGN         EYE     HAIR              SEX  GSM  \
# 16371      Bad Characters  Green Eyes  No Hair  Male Characters  NaN
# 16372     Good Characters   Blue Eyes     Bald  Male Characters  NaN
# 16373      Bad Characters  Black Eyes     Bald  Male Characters  NaN
# ...

# %% [markdown]
# ### Step6:--> Now Check the total Info of the dataset.

# %%
marvel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16376 entries, 0 to 16375
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   page_id           16376 non-null  int64
#  1   name              16376 non-null  object
#  2   urlslug           16376 non-null  object
#  3   ID                12606 non-null  object
#  4   ALIGN             13564 non-null  object
#  5   EYE               6609 non-null   object
#  6   HAIR              12112 non-null  object
#  7   SEX               15522 non-null  object
#  8   GSM               90 non-null     object
#  9   ALIVE             16373 non-null  object
#  10  APPEARANCES       15280 non-null  float64
#  11  FIRST APPEARANCE  15561 non-null  object
#  12  Year              15561 non-null  float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.6+ MB

# %%
marvel.info
# Out:
# <bound method DataFrame.info of        page_id                                 name  \
# 0         1678            Spider-Man (Peter Parker)
# 1         7139      Captain America (Steven Rogers)
# 2        64786  Wolverine (James \"Logan\" Howlett)
# 3         1868    Iron Man (Anthony \"Tony\" Stark)
# 4         2460                  Thor (Thor Odinson)
# ...        ...                                  ...
# 16371   657508                   Ru'ach (Earth-616)
# 16372   665474      Thane (Thanos' son) (Earth-616)
# 16373   695217        Tinkerer (Skrull) (Earth-616)
# 16374   708811       TK421 (Spiderling) (Earth-616)
# 16375   673702                Yologarch (Earth-616)
#
#                                        urlslug                ID  \
# 0                  \/Spider-Man_(Peter_Parker)   Secret Identity
# 1            \/Captain_America_(Steven_Rogers)   Public Identity
# 2      \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# ...

# %% [markdown]
# ### Step7:---> Perform Statatical Analysis of the dataset.

# %%
marvel.describe()
# Out:
#              page_id   APPEARANCES          Year
# count   16376.000000  15280.000000  15561.000000
# mean   300232.082377     17.033377   1984.951803
# std    253460.403399     96.372959     19.663571
# min      1025.000000      1.000000   1939.000000
# 25%     28309.500000      1.000000   1974.000000
# 50%    282578.000000      3.000000   1990.000000
# 75%    509077.000000      8.000000   2000.000000
# max    755278.000000   4043.000000   2013.000000

# %%
marvel.describe
# Out:
# <bound method NDFrame.describe of        page_id                                 name  \
# 0         1678            Spider-Man (Peter Parker)
# 1         7139      Captain America (Steven Rogers)
# 2        64786  Wolverine (James \"Logan\" Howlett)
# 3         1868    Iron Man (Anthony \"Tony\" Stark)
# 4         2460                  Thor (Thor Odinson)
# ...        ...                                  ...
# 16371   657508                   Ru'ach (Earth-616)
# 16372   665474      Thane (Thanos' son) (Earth-616)
# 16373   695217        Tinkerer (Skrull) (Earth-616)
# 16374   708811       TK421 (Spiderling) (Earth-616)
# 16375   673702                Yologarch (Earth-616)
#
#                                        urlslug                ID  \
# 0                  \/Spider-Man_(Peter_Parker)   Secret Identity
# 1            \/Captain_America_(Steven_Rogers)   Public Identity
# 2      \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# ...

# %%
marvel.size
# Out:
# 212888

# %%
marvel.columns
# Out:
# Index(['page_id', 'name', 'urlslug', 'ID', 'ALIGN', 'EYE', 'HAIR', 'SEX',
#        'GSM', 'ALIVE', 'APPEARANCES', 'FIRST APPEARANCE', 'Year'],
#       dtype='object')

# %%
marvel.shape
# Out:
# (16376, 13)

# %%
marvel.name
# Out:
# 0                  Spider-Man (Peter Parker)
# 1            Captain America (Steven Rogers)
# 2        Wolverine (James \"Logan\" Howlett)
# 3          Iron Man (Anthony \"Tony\" Stark)
# 4                        Thor (Thor Odinson)
#                         ...
# 16371                     Ru'ach (Earth-616)
# 16372        Thane (Thanos' son) (Earth-616)
# 16373          Tinkerer (Skrull) (Earth-616)
# 16374         TK421 (Spiderling) (Earth-616)
# 16375                  Yologarch (Earth-616)
# Name: name, Length: 16376, dtype: object

# %%
marvel.isna().sum()
# Out:
# page_id                 0
# name                    0
# urlslug                 0
# ID                   3770
# ALIGN                2812
# EYE                  9767
# HAIR                 4264
# SEX                   854
# GSM                 16286
# ALIVE                   3
# APPEARANCES          1096
# FIRST APPEARANCE      815
# Year                  815
# dtype: int64

# %%
marvel.describe()
# Out:
#              page_id   APPEARANCES          Year
# count   16376.000000  15280.000000  15561.000000
# mean   300232.082377     17.033377   1984.951803
# std    253460.403399     96.372959     19.663571
# min      1025.000000      1.000000   1939.000000
# 25%     28309.500000      1.000000   1974.000000
# 50%    282578.000000      3.000000   1990.000000
# 75%    509077.000000      8.000000   2000.000000
# max    755278.000000   4043.000000   2013.000000

# %%
marvel.nunique()
# Out:
# page_id             16376
# name                16376
# urlslug             16376
# ID                      4
# ALIGN                   3
# EYE                    24
# HAIR                   25
# SEX                     4
# GSM                     6
# ALIVE                   2
# APPEARANCES           358
# FIRST APPEARANCE      832
# Year                   75
# dtype: int64

# %%
marvel.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Handling Missing Data

# %%
marvel.isna().sum()
# Out:
# page_id                 0
# name                    0
# urlslug                 0
# ID                   3770
# ALIGN                2812
# EYE                  9767
# HAIR                 4264
# SEX                   854
# GSM                 16286
# ALIVE                   3
# APPEARANCES          1096
# FIRST APPEARANCE      815
# Year                  815
# dtype: int64

# %%
# page_id column irrelevant
marvel.drop('page_id',axis=1,inplace=True)

# %%
# Lets drop column 'GSM' as most of its value are null so it isnot useful
marvel1 = marvel.drop('GSM',axis=1)
marvel1.head(5)
# Out:
#                                   name  \
# 0            Spider-Man (Peter Parker)
# 1      Captain America (Steven Rogers)
# 2  Wolverine (James \"Logan\" Howlett)
# 3    Iron Man (Anthony \"Tony\" Stark)
# 4                  Thor (Thor Odinson)
#
#                                    urlslug                ID  \
# 0              \/Spider-Man_(Peter_Parker)   Secret Identity
# 1        \/Captain_America_(Steven_Rogers)   Public Identity
# 2  \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3    \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 4                    \/Thor_(Thor_Odinson)  No Dual Identity
#
#                 ALIGN         EYE        HAIR              SEX  \
# 0     Good Characters  Hazel Eyes  Brown Hair  Male Characters
# 1     Good Characters   Blue Eyes  White Hair  Male Characters
# 2  Neutral Characters   Blue Eyes  Black Hair  Male Characters
# 3     Good Characters   Blue Eyes  Black Hair  Male Characters
# ...

# %%
# urlslug is an irrelevant column , also First Appearance and Year gives same meaning
marvel1.drop(['FIRST APPEARANCE','urlslug'],axis=1,inplace=True)
marvel1.head(4)
# Out:
#                                   name               ID               ALIGN  \
# 0            Spider-Man (Peter Parker)  Secret Identity     Good Characters
# 1      Captain America (Steven Rogers)  Public Identity     Good Characters
# 2  Wolverine (James \"Logan\" Howlett)  Public Identity  Neutral Characters
# 3    Iron Man (Anthony \"Tony\" Stark)  Public Identity     Good Characters
#
#           EYE        HAIR              SEX              ALIVE  APPEARANCES  \
# 0  Hazel Eyes  Brown Hair  Male Characters  Living Characters       4043.0
# 1   Blue Eyes  White Hair  Male Characters  Living Characters       3360.0
# 2   Blue Eyes  Black Hair  Male Characters  Living Characters       3061.0
# 3   Blue Eyes  Black Hair  Male Characters  Living Characters       2961.0
#
#      Year
# 0  1962.0
# 1  1941.0
# 2  1974.0
# 3  1963.0

# %%
# ID should always be available for each character
# gender of person should be known
marvel1.dropna(subset=['ID','SEX','APPEARANCES','Year','ALIGN'],inplace=True,ignore_index=True)
marvel1.isna().sum()
# Out:
# name              0
# ID                0
# ALIGN             0
# EYE            5005
# HAIR           1549
# SEX               0
# ALIVE             0
# APPEARANCES       0
# Year              0
# dtype: int64

# %%
# remaining null values in hair and eye , lets fill it
marvel1['EYE'] = marvel1['EYE'].ffill()
marvel1['HAIR'] = marvel1['HAIR'].bfill()
marvel1.isna().sum()
# Out:
# name           0
# ID             0
# ALIGN          0
# EYE            0
# HAIR           0
# SEX            0
# ALIVE          0
# APPEARANCES    0
# Year           0
# dtype: int64

# %%
marvel1.shape
# Out:
# (9569, 9)

# %% [markdown]
# Descriptive Statistics

# %%
marvel1.describe()
# Out:
#        APPEARANCES         Year
# count  9569.000000  9569.000000
# mean     23.739680  1983.188421
# std     119.522645    21.603012
# min       1.000000  1939.000000
# 25%       1.000000  1970.000000
# 50%       4.000000  1989.000000
# 75%      11.000000  2001.000000
# max    4043.000000  2013.000000

# %%
# Check distribution of categorical variables
marvel1[['ALIGN','ID','EYE','HAIR','SEX','ALIVE']].value_counts()
# Out:
# ALIGN               ID                EYE          HAIR        SEX                ALIVE
# Bad Characters      Secret Identity   Brown Eyes   Black Hair  Male Characters    Living Characters      155
#                                       Blue Eyes    Black Hair  Male Characters    Living Characters      127
#                                       Brown Eyes   Brown Hair  Male Characters    Living Characters      115
# Good Characters     Public Identity   Brown Eyes   Black Hair  Male Characters    Living Characters       97
# Bad Characters      Public Identity   Blue Eyes    Black Hair  Male Characters    Living Characters       92
#                                                                                                         ...
# Good Characters     No Dual Identity  Red Eyes     Grey Hair   Male Characters    Deceased Characters      1
#                                                    Green Hair  Male Characters    Living Characters        1
# ...

# %% [markdown]
# Data Cleaning Phase: Handling Special Characters

# %%
marvel1
# Out:
#                                               name                ID  \
# 0                        Spider-Man (Peter Parker)   Secret Identity
# 1                  Captain America (Steven Rogers)   Public Identity
# 2              Wolverine (James \"Logan\" Howlett)   Public Identity
# 3                Iron Man (Anthony \"Tony\" Stark)   Public Identity
# 4                              Thor (Thor Odinson)  No Dual Identity
# ...                                            ...               ...
# 9564                       Peter Brown (Earth-616)  No Dual Identity
# 9565  Pukatus Jr. (Legion Personality) (Earth-616)   Secret Identity
# 9566                    Robert Michaud (Earth-616)   Secret Identity
# 9567                War (11th Century) (Earth-616)   Secret Identity
# 9568        Zubar (Legion Personality) (Earth-616)   Secret Identity
#
#                    ALIGN         EYE        HAIR              SEX  \
# 0        Good Characters  Hazel Eyes  Brown Hair  Male Characters
# ...

# %%
marvel1['name'] = marvel1['name'].str.split('(').str[0]
marvel1
# Out:
#                   name                ID               ALIGN         EYE  \
# 0          Spider-Man    Secret Identity     Good Characters  Hazel Eyes
# 1     Captain America    Public Identity     Good Characters   Blue Eyes
# 2           Wolverine    Public Identity  Neutral Characters   Blue Eyes
# 3            Iron Man    Public Identity     Good Characters   Blue Eyes
# 4                Thor   No Dual Identity     Good Characters   Blue Eyes
# ...                ...               ...                 ...         ...
# 9564      Peter Brown   No Dual Identity     Good Characters    Red Eyes
# 9565      Pukatus Jr.    Secret Identity  Neutral Characters    Red Eyes
# 9566   Robert Michaud    Secret Identity  Neutral Characters   Blue Eyes
# 9567              War    Secret Identity      Bad Characters   Blue Eyes
# 9568            Zubar    Secret Identity  Neutral Characters  Green Eyes
#
#             HAIR              SEX                ALIVE  APPEARANCES    Year
# ...

# %% [markdown]
# Visualizing the Data

# %%
# looks like a bimodal histogram
plt.hist(data=marvel1,x='Year',color='pink')
plt.show()

# %%
for i in marvel1.select_dtypes('float64'):
    sns.boxplot(data=marvel1,x=i)
    plt.show()

# %% [markdown]
# only detected outliers in appearances but it cant be removed because the count is relevant

# %%
plt.figure(figsize=(13,6))
plt.xticks(rotation=-45)
sns.barplot(data=marvel1,x='EYE',y='APPEARANCES',color='gold')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.xticks(rotation=-45)
sns.barplot(data=marvel1,x='ALIVE',y='APPEARANCES',color='purple')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.xticks(rotation=-45)
sns.barplot(data=marvel1,x='ALIGN',y='APPEARANCES',color='black')
plt.tight_layout()
plt.show()

# %% [markdown]
# Encoding Categorical Features

# %%
marvel2 = marvel1
marvel2
# Out:
#                   name                ID               ALIGN         EYE  \
# 0          Spider-Man    Secret Identity     Good Characters  Hazel Eyes
# 1     Captain America    Public Identity     Good Characters   Blue Eyes
# 2           Wolverine    Public Identity  Neutral Characters   Blue Eyes
# 3            Iron Man    Public Identity     Good Characters   Blue Eyes
# 4                Thor   No Dual Identity     Good Characters   Blue Eyes
# ...                ...               ...                 ...         ...
# 9564      Peter Brown   No Dual Identity     Good Characters    Red Eyes
# 9565      Pukatus Jr.    Secret Identity  Neutral Characters    Red Eyes
# 9566   Robert Michaud    Secret Identity  Neutral Characters   Blue Eyes
# 9567              War    Secret Identity      Bad Characters   Blue Eyes
# 9568            Zubar    Secret Identity  Neutral Characters  Green Eyes
#
#             HAIR              SEX                ALIVE  APPEARANCES    Year
# ...

# %%
# name can be encoded with label encoding
from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()
marvel2['name'] = label.fit_transform(marvel2['name'])

# or with this code - marvel2['name'].astype('category').cat.codes

# %%
# onehotencoding for ID
from sklearn.preprocessing import OneHotEncoder

onehot = OneHotEncoder(sparse_output=False)
transformed = onehot.fit_transform(marvel2[['ID']])
features = onehot.get_feature_names_out()
df = pd.DataFrame(transformed,columns=features)
marvel3 = pd.concat([marvel2,df],axis=1)
marvel3.drop(['ID'],axis=1,inplace=True)

# %%
# ordinal encoding for align
from sklearn.preprocessing import OrdinalEncoder

ord = OrdinalEncoder(categories=[['Bad Characters','Neutral Characters','Good Characters']])
val = ord.fit_transform(marvel3[['ALIGN']])
marvel3.drop('ALIGN',axis=1,inplace=True)
marvel3['ALIGN'] = val

# %%
# ordinal encoding for ALIVE
from sklearn.preprocessing import OrdinalEncoder

ord = OrdinalEncoder(categories=[['Deceased Characters','Living Characters']])
val = ord.fit_transform(marvel3[['ALIVE']])
marvel3.drop('ALIVE',axis=1,inplace=True)
marvel3['ALIVE'] = val

# %%
# label encoding
marvel3['EYE'] = marvel3['EYE'].astype('category').cat.codes
marvel3['HAIR'] = marvel3['HAIR'].astype('category').cat.codes

# %%
# onehot
new = pd.get_dummies(data=marvel3['SEX']).astype(int)
marvel4 = pd.concat([marvel3,new],axis=1)
marvel4.drop('SEX',axis=1,inplace=True)
marvel4
# Out:
#       name  EYE  HAIR  APPEARANCES    Year  ID_Known to Authorities Identity  \
# 0     7859    8     6       4043.0  1962.0                               0.0
# 1     1240    3    23       3360.0  1941.0                               0.0
# 2     8982    3     2       3061.0  1974.0                               0.0
# 3     3769    3     2       2961.0  1963.0                               0.0
# 4     8262    3     3       2258.0  1950.0                               0.0
# ...    ...  ...   ...          ...     ...                               ...
# 9564  6563   16    23          1.0  2013.0                               0.0
# 9565  6791   16     3          1.0  2013.0                               0.0
# 9566  7147    3     3          1.0  2013.0                               0.0
# 9567  8804    3    13          1.0  2013.0                               0.0
# 9568  9159    6     1          1.0  2013.0                               0.0
#
# ...

# %%
marvel4.drop('ID_Known to Authorities Identity',axis=1,inplace=True)

# %%
marvel4.rename(columns={'Year':'Appearance Year',
                        'name':'Character Name',
                        'EYE':'Eye Color',
                        'HAIR':'Hair Color',
                        'ID_No Dual Identity':'Dual Identity',
                        'ID_Public Identity':'Public Identity',
                        'ID_Secret Identity':'Secret Identity',
                        'ALIGN':'Align',
                        'ALIVE':'Alive',
                        'Agender Characters':'Agender',
                        'Female Characters':'Female',
                        'Genderfluid Characters':'Genderfluid',
                        'Male Characters':'Male',
                        'APPEARANCES':'Appearances'
},inplace=True)
marvel4
# Out:
#       Character Name  Eye Color  Hair Color  Appearances  Appearance Year  \
# 0               7859          8           6       4043.0           1962.0
# 1               1240          3          23       3360.0           1941.0
# 2               8982          3           2       3061.0           1974.0
# 3               3769          3           2       2961.0           1963.0
# 4               8262          3           3       2258.0           1950.0
# ...              ...        ...         ...          ...              ...
# 9564            6563         16          23          1.0           2013.0
# 9565            6791         16           3          1.0           2013.0
# 9566            7147          3           3          1.0           2013.0
# 9567            8804          3          13          1.0           2013.0
# 9568            9159          6           1          1.0           2013.0
#
#       Dual Identity  Public Identity  Secret Identity  Align  Alive  Agender  \
# ...

# %%
marvel.plot()
# Out:
# <Axes: >
